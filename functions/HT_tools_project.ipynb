# %%
import numpy as np
import pandas as pd
from sodapy import Socrata
import requests
import json
# client = Socrata("data.cityofnewyork.us", None)
MyAppToken='6v9nCt2L0Tftx31xuIhXQf5uv'
username='cz2527@columbia.edu'
password='Tools002'
client = Socrata('data.cityofnewyork.us',
                 MyAppToken,
                 username=username,
                 password=password)

results = client.get("8end-qv57",limit=3000)
df = pd.DataFrame.from_records(results)

# %%
df
# Out:
#      community_board            end_date_time                   event_agency  \
# 0                8,   2018-12-01T22:00:00.000               Parks Department
# 1                8,   2018-12-09T23:59:00.000               Parks Department
# 2                5,   2018-12-03T23:59:00.000               Parks Department
# 3               14,   2018-12-23T17:00:00.000  Street Activity Permit Office
# 4                7,   2018-12-23T18:00:00.000  Street Activity Permit Office
# 5           10, 12,   2018-12-02T20:00:00.000              Police Department
# 6               13,   2018-12-23T19:00:00.000               Parks Department
# 7               64,   2018-12-06T23:59:00.000               Parks Department
# 8               13,   2018-12-03T19:00:00.000               Parks Department
# 9                5,   2018-12-06T13:00:00.000               Parks Department
# 10               1,   2018-12-23T09:00:00.000               Parks Department
# 11              10,   2018-12-06T14:00:00.000               Parks Department
# 12              11,   2018-12-16T19:30:00.000               Parks Department
# 13               5,   2018-12-03T12:00:00.000               Parks Department
# 14               8,   2018-12-07T21:00:00.000               Parks Department
# 15              07,   2019-06-30T23:59:00.000               Parks Department
# 16               8,   2018-12-06T23:59:00.000               Parks Department
# 17               5,   2018-12-27T12:00:00.000               Parks Department
# 18               2,   2018-12-02T17:30:00.000               Parks Department
# 19              55,   2018-12-24T23:00:00.000               Parks Department
# 20               3,   2018-12-09T09:00:00.000               Parks Department
# 21               3,   2018-12-17T20:00:00.000               Parks Department
# 22              64,   2018-12-17T23:59:00.000               Parks Department
# 23               7,   2018-12-17T23:59:00.000               Parks Department
# 24               5,   2018-12-17T20:00:00.000               Parks Department
# 25              18,   2018-12-17T20:00:00.000               Parks Department
# 26              64,   2018-12-09T23:59:00.000               Parks Department
# 27               8,   2018-12-14T22:00:00.000               Parks Department
# 28               2,   2018-12-01T14:00:00.000               Parks Department
# 29              10,   2018-12-23T20:00:00.000               Parks Department
# ...              ...                      ...                            ...
# 2658            13,   2018-12-31T19:00:00.000               Parks Department
# 2659             5,   2019-01-01T12:00:00.000               Parks Department
# 2660            14,   2018-12-31T19:00:00.000               Parks Department
# 2661             8,   2018-12-29T17:00:00.000               Parks Department
# 2662             5,   2018-12-09T17:00:00.000               Parks Department
# 2663             4,   2018-12-31T16:01:00.000               Parks Department
# 2664            64,   2018-12-31T15:15:00.000               Parks Department
# 2665             2,   2018-12-06T20:00:00.000  Street Activity Permit Office
# 2666             8,   2018-12-22T17:00:00.000               Parks Department
# 2667             3,   2019-01-01T20:00:00.000               Parks Department
# 2668             8,   2018-12-20T17:00:00.000               Parks Department
# 2669            64,   2019-01-01T23:59:00.000               Parks Department
# 2670             2,   2018-12-31T22:00:00.000               Parks Department
# 2671             5,   2018-12-31T12:00:00.000               Parks Department
# 2672            11,   2018-12-30T19:00:00.000               Parks Department
# 2673             4,   2018-12-31T19:00:00.000               Parks Department
# 2674             5,   2018-12-31T23:59:00.000               Parks Department
# 2675             3,   2018-12-08T23:59:00.000  Street Activity Permit Office
# 2676            11,   2018-12-31T19:00:00.000               Parks Department
# 2677             5,   2018-12-06T17:00:00.000               Parks Department
# 2678            64,   2018-12-31T14:00:00.000               Parks Department
# 2679             5,   2019-01-01T23:59:00.000               Parks Department
# 2680            02,   2018-12-31T17:00:00.000               Parks Department
# 2681            64,   2019-01-01T23:59:00.000               Parks Department
# 2682        07, 09,   2019-01-01T20:00:00.000               Parks Department
# 2683             4,   2018-12-31T20:00:00.000               Parks Department
# 2684             8,   2018-12-11T15:00:00.000               Parks Department
# 2685             9,   2019-05-15T23:00:00.000  Street Activity Permit Office
# 2686            28,   2018-12-31T00:00:00.000               Parks Department
# 2687         2, 95,   2018-08-05T11:00:00.000              Police Department
#
#       event_borough event_id  \
# 0            Queens   445818
# 1         Manhattan   444352
# 2         Manhattan   434923
# 3          Brooklyn   380007
# 4          Brooklyn   389602
# 5            Queens   437602
# 6          Brooklyn   440658
# 7         Manhattan   444367
# 8          Brooklyn   440658
# 9         Manhattan   404667
# 10    Staten Island   441448
# 11            Bronx   398201
# 12           Queens   443116
# 13        Manhattan   434929
# 14            Bronx   452258
# 15            Bronx   430058
# 16        Manhattan   444352
# 17        Manhattan   434918
# 18         Brooklyn   401905
# 19         Brooklyn   434562
# 20    Staten Island   441450
# 21        Manhattan   392458
# 22        Manhattan   444367
# 23        Manhattan   392450
# 24        Manhattan   442635
# 25         Brooklyn   393907
# 26        Manhattan   444368
# 27           Queens   445818
# 28        Manhattan   447940
# 29        Manhattan   380923
# ...             ...      ...
# 2658         Queens   448512
# 2659      Manhattan   434933
# 2660       Brooklyn   448095
# 2661          Bronx   446498
# 2662      Manhattan   451519
# 2663         Queens   445012
# 2664      Manhattan   395794
# 2665      Manhattan   450274
# 2666          Bronx   446498
# 2667       Brooklyn   449422
# 2668          Bronx   446498
# 2669      Manhattan   444361
# 2670         Queens   448355
# 2671      Manhattan   434933
# 2672          Bronx   449968
# 2673         Queens   448671
# 2674      Manhattan   434936
# 2675         Queens   450334
# 2676          Bronx   449970
# 2677      Manhattan   451519
# 2678      Manhattan   393072
# 2679      Manhattan   449845
# 2680  Staten Island   436545
# 2681      Manhattan   444368
# 2682      Manhattan   447731
# 2683      Manhattan   392460
# 2684       Brooklyn   447684
# 2685       Brooklyn   425139
# 2686          Bronx   422828
# 2687  Staten Island   390009
#
#                                          event_location  \
# 0                Haym Sol. Square: Haym Salomon Square
# 1      Central Park: East 72nd Street Playground Lawns
# 2             Madison Square Park: Madison Square Park
# 3      CORTELYOU ROAD between RUGBY ROAD and ARGYLE ...
# 4              5 AVENUE between 38 STREET and 64 STREET
# 5      130 STREET between FOCH BOULEVARD and ROCKAWA...
# 6                       Calvert Vaux Park: Hobby Field
# 7     Central Park: East Meadow ,Central Park: East ...
# 8                       Calvert Vaux Park: Hobby Field
# 9                             Bryant Park: Bryant Park
# 10    Silver Lake Park: Concert Area - Forest Ave Side
# 11                  Ferry Point Park: Ferry Point Park
# 12    Alley Pond Park: Alley Springfield BBQ Area Pi...
# 13            Madison Square Park: Madison Square Park
# 14                    Bell Tower Park: Bell Tower Park
# 15    St. James Park: Handball-01 ,St. James Park: H...
# 16     Central Park: East 72nd Street Playground Lawns
# 17                  Madison Square Park: Farragut Lawn
# 18                 Fort Greene Park: South East Corner
# 19                Prospect Park: Grand Army Plaza Arch
# 20        Conference House Park: Conference House Park
# 21    Luther Gulick Playground: Luther Gulick Playgr...
# 22    Central Park: East Meadow ,Central Park: East ...
# 23    Bloomingdale Playground: Bloomingdale Playground
# 24    Central Park: Grand Army Plaza - Pulitzer Foun...
# 25                            Marine Park: Hobby Field
# 26                       Central Park: Great Hill Oval
# 27               Haym Sol. Square: Haym Salomon Square
# 28      Washington Square Park: Washington Square Park
# 29                     Jackie Robinson Park: Bandshell
# ...                                                 ...
# 2658                Springfield Park: Springfield Park
# 2659  Madison Square Park: Sol Lewitt / 25th St Lawn...
# 2660  Lt. Federico Narvaez Tot Lot: Lt. Federico Nav...
# 2661                  Bell Tower Park: Bell Tower Park
# 2662              Union Square Park: Union Square Park
# 2663          Dunningham Triangle: Dunningham Triangle
# 2664                    Central Park: Ladies' Pavilion
# 2665   HUDSON STREET between KING STREET and WEST HO...
# 2666                  Bell Tower Park: Bell Tower Park
# 2667                          Fulton Park: Fulton Park
# 2668                  Bell Tower Park: Bell Tower Park
# 2669          Central Park: Dana Discovery Center Lawn
# 2670                          Vernon Mall: Vernon Mall
# 2671  Madison Square Park: Sol Lewitt / 25th St Lawn...
# 2672                    Pelham Parkway: Pelham Parkway
# 2673   CC Moore Homestead Playground: Performance Area
# 2674                Madison Square Park: Magnolia Lawn
# 2675             37 ROAD between 74 STREET and BROADWAY
# 2676        Zimmerman Playground: Zimmerman Playground
# 2677              Union Square Park: Union Square Park
# 2678                          Central Park: Bow Bridge
# 2679          Father Duffy Square: Father Duffy Square
# 2680  Naples Playground: Basketball-01 ,Naples Playg...
# 2681                     Central Park: Great Hill Oval
# 2682  Riverside Park: 77th St-Softball-03 ,Riverside...
# 2683  Chelsea Park: Playground ,Chelsea Park: Sittin...
# 2684        Underhill Playground: Underhill Playground
# 2685  Parkside & Ocean Plaza: Parkside & Ocean Plaza...
# 2686  Pelham Bay Park and Orchard Beach: North Picni...
# 2687  South Beach Wetlands: South Beach Wetlands ,So...
#
#                                              event_name event_street_side  \
# 0                                  Lighting the Menorah               NaN
# 1     E. 72nd Palyground Lawn  Winter Closure until ...               NaN
# 2                                      Lawn Maintenance               NaN
# 3                                 Cortelyou Greenmarket             North
# 4             Sunset Park BID 5th Avenue Sidewalk Sales              Both
# 5                                    Parade on Rockaway              Full
# 6                               Model Helicopter Flying               NaN
# 7     East Meadow  Landscape  Winter Closure Nov 23,...               NaN
# 8                               Model Helicopter Flying               NaN
# 9                                              Juggling               NaN
# 10                     NYRR Open Run - Silver Lake Park               NaN
# 11                              Radio Control Airplanes               NaN
# 12                  Rangers' Choice: Fire Making Skills               NaN
# 13                                     Lawn Maintenance               NaN
# 14                                     Menorah lighting               NaN
# 15                  St. James Handball & Tennis Closure               NaN
# 16    E. 72nd Palyground Lawn  Winter Closure until ...               NaN
# 17                                     Lawn Maintenance               NaN
# 18                                      Menorah Display               NaN
# 19                  Christmas Tree Lighting and Display               NaN
# 20                NYRR Open Run - Conference House Park               NaN
# 21                                         Construction               NaN
# 22    East Meadow  Landscape  Winter Closure Nov 23,...               NaN
# 23                                         Construction               NaN
# 24                            Holiday Live Tree Display               NaN
# 25         Flying Radio Controled Model Planes at Field               NaN
# 26    Great Hill Winter closure Oct 29, 2018- May 4,...               NaN
# 27                                 Lighting the Menorah               NaN
# 28                                    Puppy Picture Day               NaN
# 29                              2018 NO AMPLIFIED SOUND               NaN
# ...                                                 ...               ...
# 2658              Annual Tree Lighting Springfield Park               NaN
# 2659                                   Lawn Maintenance               NaN
# 2660                                           Chanukah               NaN
# 2661                               Manger for Christmas               NaN
# 2662                   Chanukah Menorah in Union Square               NaN
# 2663                              Holiday Tree Lighting               NaN
# 2664                                        Celebration               NaN
# 2665                NYFTA _ Twitter Sports is happening              West
# 2666                               Manger for Christmas               NaN
# 2667  The Stuyvesant Heights Parents Assoc Tree Ligh...               NaN
# 2668                               Manger for Christmas               NaN
# 2669   Dana Ctr  Lawn  Winter Closure until May 4, 2019               NaN
# 2670  2018 LIC Holiday Tree and Lighting in the Vern...               NaN
# 2671                                   Lawn Maintenance               NaN
# 2672                                  Holiday Lightings               NaN
# 2673          CC Moore Park Holiday Tree Lighting Event               NaN
# 2674                                   Lawn Maintenance               NaN
# 2675  Annual Interfaith Holiday Celeberations at Div...              Both
# 2676                             Allerton Tree Lighting               NaN
# 2677                   Chanukah Menorah in Union Square               NaN
# 2678                                        Celebration               NaN
# 2679                           New Year's Eve 2018-2019               NaN
# 2680                                  after care recess               NaN
# 2681  Great Hill Winter closure Oct 29, 2018- May 4,...               NaN
# 2682                            capital project 79th st               NaN
# 2683                                       construction               NaN
# 2684                                    Menorah Display               NaN
# 2685                               Caribbeing Container              Full
# 2686                                Storm Damage Repair               NaN
# 2687  Staten Island TriDuathlon to benefit the Rocco...               NaN
#
#                 event_type police_precinct          start_date_time  \
# 0            Special Event           107,   2018-12-01T12:00:00.000
# 1            Special Event            19,   2018-12-09T00:00:00.000
# 2            Special Event            13,   2018-12-03T00:01:00.000
# 3           Farmers Market            70,   2018-12-23T08:00:00.000
# 4            Sidewalk Sale            72,   2018-12-23T11:00:00.000
# 5                   Parade      106, 113,   2018-12-02T18:00:00.000
# 6            Special Event            60,   2018-12-23T08:00:00.000
# 7            Special Event            22,   2018-12-06T00:00:00.000
# 8            Special Event            60,   2018-12-03T08:00:00.000
# 9            Special Event            14,   2018-12-06T12:00:00.000
# 10           Special Event           120,   2018-12-23T08:00:00.000
# 11           Special Event            45,   2018-12-06T08:00:00.000
# 12           Special Event           111,   2018-12-16T18:00:00.000
# 13           Special Event            13,   2018-12-03T00:01:00.000
# 14           Special Event            50,   2018-12-07T16:00:00.000
# 15            Construction            52,   2018-07-10T00:00:00.000
# 16           Special Event            19,   2018-12-06T00:00:00.000
# 17           Special Event            13,   2018-12-27T00:01:00.000
# 18           Special Event            88,   2018-12-02T17:00:00.000
# 19           Special Event            78,   2018-12-24T20:00:00.000
# 20           Special Event           123,   2018-12-09T08:00:00.000
# 21            Construction             7,   2018-12-17T08:00:00.000
# 22           Special Event            22,   2018-12-17T00:00:00.000
# 23           Special Event            24,   2018-12-17T00:00:00.000
# 24           Special Event            18,   2018-12-17T06:00:00.000
# 25           Special Event            63,   2018-12-17T08:00:00.000
# 26           Special Event            22,   2018-12-09T00:00:00.000
# 27           Special Event           107,   2018-12-14T12:00:00.000
# 28           Special Event             6,   2018-12-01T12:00:00.000
# 29           Special Event            30,   2018-12-23T08:00:00.000
# ...                    ...             ...                      ...
# 2658         Special Event           105,   2018-12-31T17:00:00.000
# 2659         Special Event            13,   2019-01-01T00:01:00.000
# 2660         Special Event            70,   2018-12-31T16:00:00.000
# 2661         Special Event            50,   2018-12-29T14:00:00.000
# 2662         Special Event            13,   2018-12-09T14:00:00.000
# 2663         Special Event           110,   2018-12-31T16:00:00.000
# 2664         Special Event            22,   2018-12-31T15:00:00.000
# 2665          Street Event          1, 6,   2018-12-06T08:00:00.000
# 2666         Special Event            50,   2018-12-22T14:00:00.000
# 2667         Special Event            81,   2019-01-01T12:00:00.000
# 2668         Special Event            50,   2018-12-20T14:00:00.000
# 2669         Special Event            22,   2019-01-01T00:00:00.000
# 2670         Special Event           108,   2018-12-31T17:00:00.000
# 2671         Special Event            13,   2018-12-31T00:01:00.000
# 2672         Special Event            49,   2018-12-30T18:00:00.000
# 2673         Special Event           110,   2018-12-31T16:00:00.000
# 2674         Special Event            13,   2018-12-31T00:01:00.000
# 2675           Plaza Event           115,   2018-12-08T10:00:00.000
# 2676         Special Event            49,   2018-12-31T18:00:00.000
# 2677         Special Event            13,   2018-12-06T14:00:00.000
# 2678         Special Event            22,   2018-12-31T12:00:00.000
# 2679         Special Event            18,   2019-01-01T00:00:00.000
# 2680         Special Event           122,   2018-12-31T14:00:00.000
# 2681         Special Event            22,   2019-01-01T00:00:00.000
# 2682          Construction        20, 26,   2019-01-01T08:00:00.000
# 2683          Construction            10,   2018-12-31T08:00:00.000
# 2684         Special Event            77,   2018-11-30T17:00:00.000
# 2685           Plaza Event            71,   2018-06-15T01:00:00.000
# 2686          Construction            45,   2018-06-05T12:00:00.000
# 2687  Athletic Race / Tour           122,   2018-08-05T06:30:00.000
#
#                   street_closure_type
# 0                                 N/A
# 1                                 N/A
# 2                                 N/A
# 3     Sidewalk and Curb Lane Closure
# 4        Sidewalk and Street Closure
# 5                Full Street Closure
# 6                                 N/A
# 7                                 N/A
# 8                                 N/A
# 9                                 N/A
# 10                                N/A
# 11                                N/A
# 12                                N/A
# 13                                N/A
# 14                                N/A
# 15                                N/A
# 16                                N/A
# 17                                N/A
# 18                                N/A
# 19                                N/A
# 20                                N/A
# 21                                N/A
# 22                                N/A
# 23                                N/A
# 24                                N/A
# 25                                N/A
# 26                                N/A
# 27                                N/A
# 28                                N/A
# 29                                N/A
# ...                               ...
# 2658                              N/A
# 2659                              N/A
# 2660                              N/A
# 2661                              N/A
# 2662                              N/A
# 2663                              N/A
# 2664                              N/A
# 2665                   Curb Lane Only
# 2666                              N/A
# 2667                              N/A
# 2668                              N/A
# 2669                              N/A
# 2670                              N/A
# 2671                              N/A
# 2672                              N/A
# 2673                              N/A
# 2674                              N/A
# 2675        Partial Sidewalk Closure
# 2676                              N/A
# 2677                              N/A
# 2678                              N/A
# 2679                              N/A
# 2680                              N/A
# 2681                              N/A
# 2682                              N/A
# 2683                              N/A
# 2684                              N/A
# 2685                Pedestrian Plaza
# 2686                              N/A
# 2687             Full Street Closure
#
# [2688 rows x 12 columns]

# %%
def get_address(event_index):
    if 0<=event_index<len(df):
        address = df['event_location'].iloc[event_index]
        return address 
    else:
        print('The index is out of range, please look carefully and try again!')
        event_index = int(input('Please enter the index of the event that you are interested in:'))
        address = df['event_location'].iloc[event_index]
        return address

# %%
def get_zip_code(address):
    api_key = 'AIzaSyAf9b6B8Bd9De9JtheV7FLnRfC9lLcSzzo'
    address=address.replace(' ','+')
    url='https://maps.googleapis.com/maps/api/place/textsearch/json?key=%s&query=%s&fields=formatted_address'% (api_key,address) 
    response = requests.get(url)
    result = json.loads(response.content)
    try:
        zip_code = result['results'][0]['formatted_address'].split('NY ')[1].split(',')[0]  # get zip code
        return zip_code
    except:
        return 'The location is ambiguous, you should search for detailed information by yourself.'
        pass

# %%
def get_heatmap():
    import folium
    address_1 = []            #list of address
    for i in range(len(df)):
        address_1.append(get_address(i))
        
    zip_code_list = []        #list of zip code(raw)
    for i in range(len(address_1)):
        zip_code_list.append(get_zip_code(address_1[i]))
        
    zip_code_list2 = []       #remove the wrong return
    for i in range(len(zip_code_list)):
        if zip_code_list[i] != 'The location is ambiguous, you should search for detailed information by yourself.':
            zip_code_list2.append(zip_code_list[i])
            
    zip_code_list3 = list(set(zip_code_list2))  #unique zip & sort
    zip_code_list3.sort()
    
    zip_count_list = []       #list of sizes of each zip code
    for i in range(len(zip_code_list3)):
        zip_count_list.append(zip_code_list2.count(zip_code_list3[i]))

    dict_zip = {"Zip Code" : zip_code_list3,
                "Size" : zip_count_list}
    sizes = pd.DataFrame(dict_zip)
    
    m = folium.Map(location = [40.7589,-73.9851],zoom_start=11)    #draw the heatmap

    m.choropleth(geo_data='zipcode.geojson', data=sizes,
                 columns=[ 'Zip Code','Size'],
                 key_on='feature.properties.postalCode',
                 fill_color='RdYlGn', fill_opacity=0.7, line_opacity=0.8,
                 legend_name='Distribution of Incidents')
    folium.LayerControl().add_to(m)
    
    return m

# %%
# address_1 = []            #list of address
# for i in range(len(df)):
#     address_1.append(get_address(i))

# %%
# zip_code_list = []        #list of zip code(raw)
# for i in range(len(address_1)):
#     zip_code_list.append(get_zip_code(address_1[i]))

# %%
# zip_code_list2 = []       #remove the wrong return
# for i in range(len(zip_code_list)):
#     if zip_code_list[i] != 'The location is ambiguous, you should search for detailed information by yourself.':
#         zip_code_list2.append(zip_code_list[i])

# %%
# zip_code_list3 = list(set(zip_code_list2))  #unique zip & sort
# zip_code_list3.sort()

# %%
# zip_count_list = []                         #list of sizes of each zip code
# for i in range(len(zip_code_list3)):
#     zip_count_list.append(zip_code_list2.count(zip_code_list3[i]))

# %%
# dict_zip = {"Zip Code" : zip_code_list3,
#             "Size" : zip_count_list}
# sizes = pd.DataFrame(dict_zip)

# %%
# import folium
# m = folium.Map(location = [40.7589,-73.9851],zoom_start=11)

# m.choropleth(geo_data='zipcode.geojson', data=sizes,
#              columns=[ 'Zip Code','Size'],
#              key_on='feature.properties.postalCode',
#              fill_color='RdYlGn', fill_opacity=0.7, line_opacity=0.8,
#              legend_name='Distribution of Incidents')
# folium.LayerControl().add_to(m)

# %%
# m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# zip_code_list2.count('10005')  #test

# %%
# get_zip_code(address_1[1])     #test

# %%
# def get_latlng(address):
#     api_key = 'AIzaSyAf9b6B8Bd9De9JtheV7FLnRfC9lLcSzzo'
#     address=address.replace(' ','+')
#     url='https://maps.googleapis.com/maps/api/place/textsearch/json?key=%s&query=%s&fields=formatted_address'% (api_key,address) 
#     response = requests.get(url)
#     result = json.loads(response.content)
#     try:
#         location = result['results'][0]['geometry']['location']
#         lat = location['lat']    
#         lng = location['lng'] 
#         return lat, lng
#     except:
#         return 'The location is ambiguous, you should search for detailed information by yourself.'
#         pass

# %%
# coordinate_1 = []
# for i in range(len(address_1)):
#     coordinate_1.append(get_latlng(address_1[i]))

# %%
# coordinate_2 = []                     # list of coordinates (cleaned data)
# for i in range(len(coordinate_1)):
#     if coordinate_1[i] != 'The location is ambiguous, you should search for detailed information by yourself.':
#         coordinate_2.append(coordinate_1[i])
