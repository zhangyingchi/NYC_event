# %%
import pandas as pd
from sodapy import Socrata
# client = Socrata("data.cityofnewyork.us", None)
MyAppToken='6v9nCt2L0Tftx31xuIhXQf5uv'
username='cz2527@columbia.edu'
password='Tools002'
client = Socrata('data.cityofnewyork.us',
                 MyAppToken,
                 username=username,
                 password=password)

results = client.get("8end-qv57",limit=3000)
df = pd.DataFrame.from_records(results)

# %%
df
# Out:
#      community_board            end_date_time                   event_agency  \
# 0                8,   2018-12-01T22:00:00.000               Parks Department
# 1                8,   2018-12-09T23:59:00.000               Parks Department
# 2                5,   2018-12-03T23:59:00.000               Parks Department
# 3               14,   2018-12-23T17:00:00.000  Street Activity Permit Office
# 4                7,   2018-12-23T18:00:00.000  Street Activity Permit Office
# 5           10, 12,   2018-12-02T20:00:00.000              Police Department
# 6               13,   2018-12-23T19:00:00.000               Parks Department
# 7               64,   2018-12-06T23:59:00.000               Parks Department
# 8               13,   2018-12-03T19:00:00.000               Parks Department
# 9                5,   2018-12-06T13:00:00.000               Parks Department
# 10               1,   2018-12-23T09:00:00.000               Parks Department
# 11              10,   2018-12-06T14:00:00.000               Parks Department
# 12              11,   2018-12-16T19:30:00.000               Parks Department
# 13               5,   2018-12-03T12:00:00.000               Parks Department
# 14               8,   2018-12-07T21:00:00.000               Parks Department
# 15              07,   2019-06-30T23:59:00.000               Parks Department
# 16               8,   2018-12-06T23:59:00.000               Parks Department
# 17              55,   2018-11-30T17:00:00.000               Parks Department
# 18               5,   2018-12-27T12:00:00.000               Parks Department
# 19               2,   2018-12-02T17:30:00.000               Parks Department
# 20              55,   2018-12-24T23:00:00.000               Parks Department
# 21               3,   2018-12-09T09:00:00.000               Parks Department
# 22               3,   2018-12-17T20:00:00.000               Parks Department
# 23              64,   2018-12-17T23:59:00.000               Parks Department
# 24               7,   2018-12-17T23:59:00.000               Parks Department
# 25               5,   2018-12-17T20:00:00.000               Parks Department
# 26              18,   2018-12-17T20:00:00.000               Parks Department
# 27              64,   2018-12-09T23:59:00.000               Parks Department
# 28               8,   2018-12-14T22:00:00.000               Parks Department
# 29               2,   2018-12-01T14:00:00.000               Parks Department
# ...              ...                      ...                            ...
# 2616             2,   2018-12-15T14:00:00.000               Parks Department
# 2617             5,   2018-12-30T23:59:00.000               Parks Department
# 2618             7,   2018-12-06T18:00:00.000               Parks Department
# 2619            11,   2018-12-30T23:00:00.000               Parks Department
# 2620            10,   2018-12-05T20:00:00.000               Parks Department
# 2621             3,   2018-12-08T19:00:00.000               Parks Department
# 2622             7,   2018-12-10T18:00:00.000               Parks Department
# 2623            13,   2018-12-29T19:00:00.000               Parks Department
# 2624             7,   2018-12-05T18:00:00.000               Parks Department
# 2625             7,   2018-12-30T23:59:00.000               Parks Department
# 2626             3,   2018-12-30T20:00:00.000               Parks Department
# 2627            16,   2018-12-21T16:15:00.000  Street Activity Permit Office
# 2628            64,   2018-12-30T23:59:00.000               Parks Department
# 2629             5,   2018-12-30T23:59:00.000               Parks Department
# 2630             6,   2018-12-08T19:00:00.000               Parks Department
# 2631             2,   2018-12-04T22:00:00.000  Street Activity Permit Office
# 2632             2,   2018-12-30T20:00:00.000  Street Activity Permit Office
# 2633            64,   2018-12-30T01:00:00.000               Parks Department
# 2634             8,   2018-12-01T18:00:00.000  Street Activity Permit Office
# 2635             8,   2018-12-02T17:00:00.000  Street Activity Permit Office
# 2636            11,   2018-12-30T09:00:00.000               Parks Department
# 2637             6,   2018-12-02T19:00:00.000               Parks Department
# 2638             4,   2018-12-30T20:00:00.000               Parks Department
# 2639             6,   2018-12-09T19:00:00.000               Parks Department
# 2640            11,   2018-12-29T19:00:00.000               Parks Department
# 2641             6,   2018-12-05T19:00:00.000               Parks Department
# 2642            81,   2018-12-30T12:00:00.000               Parks Department
# 2643             9,   2019-05-15T23:00:00.000  Street Activity Permit Office
# 2644            28,   2018-12-31T00:00:00.000               Parks Department
# 2645         2, 95,   2018-08-05T11:00:00.000              Police Department
#
#       event_borough event_id  \
# 0            Queens   445818
# 1         Manhattan   444352
# 2         Manhattan   434923
# 3          Brooklyn   380007
# 4          Brooklyn   389602
# 5            Queens   437602
# 6          Brooklyn   440658
# 7         Manhattan   444367
# 8          Brooklyn   440658
# 9         Manhattan   404667
# 10    Staten Island   441448
# 11            Bronx   398201
# 12           Queens   443116
# 13        Manhattan   434929
# 14            Bronx   452258
# 15            Bronx   430058
# 16        Manhattan   444352
# 17         Brooklyn   447776
# 18        Manhattan   434918
# 19         Brooklyn   401905
# 20         Brooklyn   434562
# 21    Staten Island   441450
# 22        Manhattan   392458
# 23        Manhattan   444367
# 24        Manhattan   392450
# 25        Manhattan   442635
# 26         Brooklyn   393907
# 27        Manhattan   444368
# 28           Queens   445818
# 29        Manhattan   447940
# ...             ...      ...
# 2616      Manhattan   452203
# 2617      Manhattan   434900
# 2618      Manhattan   448924
# 2619      Manhattan   444983
# 2620       Brooklyn   452100
# 2621       Brooklyn   393368
# 2622      Manhattan   448924
# 2623         Queens   448512
# 2624      Manhattan   448924
# 2625      Manhattan   441856
# 2626      Manhattan   392458
# 2627       Brooklyn   449682
# 2628      Manhattan   338385
# 2629      Manhattan   434936
# 2630      Manhattan   445106
# 2631      Manhattan   450030
# 2632      Manhattan   382992
# 2633      Manhattan   444351
# 2634      Manhattan   446479
# 2635          Bronx   445433
# 2636         Queens   441265
# 2637      Manhattan   445106
# 2638      Manhattan   392460
# 2639      Manhattan   445106
# 2640          Bronx   449970
# 2641      Manhattan   445106
# 2642         Queens   387670
# 2643       Brooklyn   425139
# 2644          Bronx   422828
# 2645  Staten Island   390009
#
#                                          event_location  \
# 0                Haym Sol. Square: Haym Salomon Square
# 1      Central Park: East 72nd Street Playground Lawns
# 2             Madison Square Park: Madison Square Park
# 3      CORTELYOU ROAD between RUGBY ROAD and ARGYLE ...
# 4              5 AVENUE between 38 STREET and 64 STREET
# 5      130 STREET between FOCH BOULEVARD and ROCKAWA...
# 6                       Calvert Vaux Park: Hobby Field
# 7     Central Park: East Meadow ,Central Park: East ...
# 8                       Calvert Vaux Park: Hobby Field
# 9                             Bryant Park: Bryant Park
# 10    Silver Lake Park: Concert Area - Forest Ave Side
# 11                  Ferry Point Park: Ferry Point Park
# 12    Alley Pond Park: Alley Springfield BBQ Area Pi...
# 13            Madison Square Park: Madison Square Park
# 14                    Bell Tower Park: Bell Tower Park
# 15    St. James Park: Handball-01 ,St. James Park: H...
# 16     Central Park: East 72nd Street Playground Lawns
# 17                 Prospect Park: Park Circle Entrance
# 18                  Madison Square Park: Farragut Lawn
# 19                 Fort Greene Park: South East Corner
# 20                Prospect Park: Grand Army Plaza Arch
# 21        Conference House Park: Conference House Park
# 22    Luther Gulick Playground: Luther Gulick Playgr...
# 23    Central Park: East Meadow ,Central Park: East ...
# 24    Bloomingdale Playground: Bloomingdale Playground
# 25    Central Park: Grand Army Plaza - Pulitzer Foun...
# 26                            Marine Park: Hobby Field
# 27                       Central Park: Great Hill Oval
# 28               Haym Sol. Square: Haym Salomon Square
# 29      Washington Square Park: Washington Square Park
# ...                                                 ...
# 2616           Washington Square Park: Garibaldi Plaza
# 2617                    Madison Square Park: Oval Lawn
# 2618      Richard Tucker Square: Richard Tucker Square
# 2619  Randall's Island Park: Wards Meadow Fields-Soc...
# 2620              Leif Ericson Park: Leif Ericson Park
# 2621                      Herbert Von King Park: Plaza
# 2622      Richard Tucker Square: Richard Tucker Square
# 2623                Springfield Park: Springfield Park
# 2624      Richard Tucker Square: Richard Tucker Square
# 2625  Damrosch Park: Damrosch Park ,Damrosch Park: B...
# 2626  Luther Gulick Playground: Luther Gulick Playgr...
# 2627  Osborn Street Plaza: Osborn Street Plaza OSBOR...
# 2628            Central Park: Belvedere Castle Terrace
# 2629                Madison Square Park: Magnolia Lawn
# 2630                 Sutton Place Park: Pig Plaza 57th
# 2631   MERCER STREET between WEST HOUSTON STREET and...
# 2632   PRINCE STREET between MOTT STREET and MULBERR...
# 2633  Central Park: East 102nd St Clay Oval ,Central...
# 2634    East 91st Street Plaza: East 91st Street Plaza
# 2635   WEST 239 STREET between HENRY HUDSON PARKWAY ...
# 2636                  Cunningham Park: Cunningham Park
# 2637                 Sutton Place Park: Pig Plaza 57th
# 2638  Chelsea Park: Playground ,Chelsea Park: Sittin...
# 2639                 Sutton Place Park: Pig Plaza 57th
# 2640        Zimmerman Playground: Zimmerman Playground
# 2641                 Sutton Place Park: Pig Plaza 57th
# 2642   Flushing Meadows Corona Park: Vatican Pavillion
# 2643  Parkside & Ocean Plaza: Parkside & Ocean Plaza...
# 2644  Pelham Bay Park and Orchard Beach: North Picni...
# 2645  South Beach Wetlands: South Beach Wetlands ,So...
#
#                                              event_name event_street_side  \
# 0                                  Lighting the Menorah               NaN
# 1     E. 72nd Palyground Lawn  Winter Closure until ...               NaN
# 2                                      Lawn Maintenance               NaN
# 3                                 Cortelyou Greenmarket             North
# 4             Sunset Park BID 5th Avenue Sidewalk Sales              Both
# 5                                    Parade on Rockaway              Full
# 6                               Model Helicopter Flying               NaN
# 7     East Meadow  Landscape  Winter Closure Nov 23,...               NaN
# 8                               Model Helicopter Flying               NaN
# 9                                              Juggling               NaN
# 10                     NYRR Open Run - Silver Lake Park               NaN
# 11                              Radio Control Airplanes               NaN
# 12                  Rangers' Choice: Fire Making Skills               NaN
# 13                                     Lawn Maintenance               NaN
# 14                                     Menorah lighting               NaN
# 15                  St. James Handball & Tennis Closure               NaN
# 16    E. 72nd Palyground Lawn  Winter Closure until ...               NaN
# 17                               menorah at park circle               NaN
# 18                                     Lawn Maintenance               NaN
# 19                                      Menorah Display               NaN
# 20                  Christmas Tree Lighting and Display               NaN
# 21                NYRR Open Run - Conference House Park               NaN
# 22                                         Construction               NaN
# 23    East Meadow  Landscape  Winter Closure Nov 23,...               NaN
# 24                                         Construction               NaN
# 25                            Holiday Live Tree Display               NaN
# 26         Flying Radio Controled Model Planes at Field               NaN
# 27    Great Hill Winter closure Oct 29, 2018- May 4,...               NaN
# 28                                 Lighting the Menorah               NaN
# 29                                    Puppy Picture Day               NaN
# ...                                                 ...               ...
# 2616  Won't Be Erased: Science and Medicine refuse t...               NaN
# 2617                                   Lawn Maintenance               NaN
# 2618                       Menorah Display and lighting               NaN
# 2619                                  Turf Construction               NaN
# 2620                          Chanukah Menorah lighting               NaN
# 2621                                      TREE LIGHTING               NaN
# 2622                       Menorah Display and lighting               NaN
# 2623              Annual Tree Lighting Springfield Park               NaN
# 2624                       Menorah Display and lighting               NaN
# 2625                                   Big Apple Circus               NaN
# 2626                                       Construction               NaN
# 2627          Winter Solstice Make Music Parade Kickoff              Full
# 2628            Belvedere Castle year-long construction               NaN
# 2629                                   Lawn Maintenance               NaN
# 2630                             Public Menorah Display               NaN
# 2631                              EMPIRE INTERIOR EVENT              East
# 2632                       Old Cathedral Outdoor Market             North
# 2633  E. 102nd Landscape Winter Closure until April ...               NaN
# 2634              Holiday Tree Lighting and Sing a Long              Full
# 2635                                   Menorah lighting              Full
# 2636                    NYRR Open Run - Cunningham Park               NaN
# 2637                             Public Menorah Display               NaN
# 2638                                       construction               NaN
# 2639                             Public Menorah Display               NaN
# 2640                             Allerton Tree Lighting               NaN
# 2641                             Public Menorah Display               NaN
# 2642                    Sunday Holy Hours DECEMBER 2018               NaN
# 2643                               Caribbeing Container              Full
# 2644                                Storm Damage Repair               NaN
# 2645  Staten Island TriDuathlon to benefit the Rocco...               NaN
#
#                 event_type police_precinct          start_date_time  \
# 0            Special Event           107,   2018-12-01T12:00:00.000
# 1            Special Event            19,   2018-12-09T00:00:00.000
# 2            Special Event            13,   2018-12-03T00:01:00.000
# 3           Farmers Market            70,   2018-12-23T08:00:00.000
# 4            Sidewalk Sale            72,   2018-12-23T11:00:00.000
# 5                   Parade      106, 113,   2018-12-02T18:00:00.000
# 6            Special Event            60,   2018-12-23T08:00:00.000
# 7            Special Event            22,   2018-12-06T00:00:00.000
# 8            Special Event            60,   2018-12-03T08:00:00.000
# 9            Special Event            14,   2018-12-06T12:00:00.000
# 10           Special Event           120,   2018-12-23T08:00:00.000
# 11           Special Event            45,   2018-12-06T08:00:00.000
# 12           Special Event           111,   2018-12-16T18:00:00.000
# 13           Special Event            13,   2018-12-03T00:01:00.000
# 14           Special Event            50,   2018-12-07T16:00:00.000
# 15            Construction            52,   2018-07-10T00:00:00.000
# 16           Special Event            19,   2018-12-06T00:00:00.000
# 17           Special Event            78,   2018-11-30T08:00:00.000
# 18           Special Event            13,   2018-12-27T00:01:00.000
# 19           Special Event            88,   2018-12-02T17:00:00.000
# 20           Special Event            78,   2018-12-24T20:00:00.000
# 21           Special Event           123,   2018-12-09T08:00:00.000
# 22            Construction             7,   2018-12-17T08:00:00.000
# 23           Special Event            22,   2018-12-17T00:00:00.000
# 24           Special Event            24,   2018-12-17T00:00:00.000
# 25           Special Event            18,   2018-12-17T06:00:00.000
# 26           Special Event            63,   2018-12-17T08:00:00.000
# 27           Special Event            22,   2018-12-09T00:00:00.000
# 28           Special Event           107,   2018-12-14T12:00:00.000
# 29           Special Event             6,   2018-12-01T12:00:00.000
# ...                    ...             ...                      ...
# 2616         Special Event             6,   2018-12-15T12:00:00.000
# 2617         Special Event            13,   2018-12-30T00:01:00.000
# 2618         Special Event            20,   2018-12-06T08:00:00.000
# 2619          Construction            25,   2018-12-30T06:00:00.000
# 2620         Special Event            68,   2018-12-05T17:00:00.000
# 2621         Special Event            79,   2018-12-08T17:00:00.000
# 2622         Special Event            20,   2018-12-10T08:00:00.000
# 2623         Special Event           105,   2018-12-29T17:00:00.000
# 2624         Special Event            20,   2018-12-05T08:00:00.000
# 2625         Special Event            20,   2018-12-30T00:00:00.000
# 2626          Construction             7,   2018-12-30T08:00:00.000
# 2627           Plaza Event            73,   2018-12-21T16:00:00.000
# 2628          Construction            22,   2018-12-30T00:00:00.000
# 2629         Special Event            13,   2018-12-30T00:01:00.000
# 2630         Special Event            17,   2018-12-08T12:00:00.000
# 2631      Production Event             1,   2018-12-03T07:00:00.000
# 2632         Sidewalk Sale             5,   2018-12-30T09:00:00.000
# 2633         Special Event            22,   2018-12-30T00:00:00.000
# 2634           Plaza Event            19,   2018-12-01T17:00:00.000
# 2635       Religious Event            50,   2018-12-02T16:00:00.000
# 2636         Special Event           107,   2018-12-30T08:00:00.000
# 2637         Special Event            17,   2018-12-02T12:00:00.000
# 2638          Construction            10,   2018-12-30T08:00:00.000
# 2639         Special Event            17,   2018-12-09T12:00:00.000
# 2640         Special Event            49,   2018-12-29T18:00:00.000
# 2641         Special Event            17,   2018-12-05T12:00:00.000
# 2642         Special Event           110,   2018-12-30T10:30:00.000
# 2643           Plaza Event            71,   2018-06-15T01:00:00.000
# 2644          Construction            45,   2018-06-05T12:00:00.000
# 2645  Athletic Race / Tour           122,   2018-08-05T06:30:00.000
#
#                   street_closure_type
# 0                                 N/A
# 1                                 N/A
# 2                                 N/A
# 3     Sidewalk and Curb Lane Closure
# 4        Sidewalk and Street Closure
# 5                Full Street Closure
# 6                                 N/A
# 7                                 N/A
# 8                                 N/A
# 9                                 N/A
# 10                                N/A
# 11                                N/A
# 12                                N/A
# 13                                N/A
# 14                                N/A
# 15                                N/A
# 16                                N/A
# 17                                N/A
# 18                                N/A
# 19                                N/A
# 20                                N/A
# 21                                N/A
# 22                                N/A
# 23                                N/A
# 24                                N/A
# 25                                N/A
# 26                                N/A
# 27                                N/A
# 28                                N/A
# 29                                N/A
# ...                               ...
# 2616                              N/A
# 2617                              N/A
# 2618                              N/A
# 2619                              N/A
# 2620                              N/A
# 2621                              N/A
# 2622                              N/A
# 2623                              N/A
# 2624                              N/A
# 2625                              N/A
# 2626                              N/A
# 2627                Pedestrian Plaza
# 2628                              N/A
# 2629                              N/A
# 2630                              N/A
# 2631                   Curb Lane Only
# 2632                   Curb Lane Only
# 2633                              N/A
# 2634                Pedestrian Plaza
# 2635             Full Street Closure
# 2636                              N/A
# 2637                              N/A
# 2638                              N/A
# 2639                              N/A
# 2640                              N/A
# 2641                              N/A
# 2642                              N/A
# 2643                Pedestrian Plaza
# 2644                              N/A
# 2645             Full Street Closure
#
# [2646 rows x 12 columns]

# %%
len(df['event_name'].unique())
# Out:
# 383

# %%
import numpy as np
a = df['event_location'].iloc[1]
a
# Out:
# 'Central Park: Dana Discovery Center Lawn '

# %% [markdown]
# # route

# %%
#input a index and get the event name 
def get_location(df):
    event_index = int(input('Please enter the index of the event that you are interested in:'))
    if 0<=event_index<len(df):
        a = df['event_location'].iloc[event_index]
        return a 
    else:
        print('The index is out of range, please look carefully and try again!')
        event_index = int(input('Please enter the index of the event that you are interested in:'))
        a = df['event_location'].iloc[event_index]
        return a

# %%
#input the event name and get the lat and lgt
import requests
import json
api_key = 'AIzaSyAf9b6B8Bd9De9JtheV7FLnRfC9lLcSzzo'
def get_latlng(address):
    api_key = 'AIzaSyAf9b6B8Bd9De9JtheV7FLnRfC9lLcSzzo'
    address=address.replace(' ','+')
    url='https://maps.googleapis.com/maps/api/place/textsearch/json?key=%s&query=%s&fields=formatted_address'% (api_key,address) 
    response = requests.get(url)
    result = json.loads(response.content)
    try:
        location = result['results'][0]['geometry']['location']
        lat = location['lat']    
        lng = location['lng'] 
        return lat, lng
    except:
        return 'The location is ambiguous, you should search for detailed information by yourself.'
        pass

# %%
get_location('Central Park: Rumsey Playfield ,Central Park: Bandshell Plaza ')
# Out:
# (40.7726834, -73.9710283)

# %% [markdown]
# # text cloud

# %%
from scipy.misc.pilutil import imread, imsave,imresize
import matplotlib.pyplot as plt

# %%
type(df['event_name'])
# Out:
# pandas.core.series.Series

# %%
import nltk
from wordcloud import WordCloud, STOPWORDS
motive=df['event_name'].str.cat(sep = '-')

# motive=df['event_name'].str().lower().str.cat(sep=' ')
words=nltk.tokenize.word_tokenize(motive)

# words = [i for i in df['event_name']]
# print(words)

word_dist = nltk.FreqDist(words)
stopwords = nltk.corpus.stopwords.words('english')

origin_image = imread("20181201194036.png")
origin_mask = origin_image
words_without_stop = nltk.FreqDist(w for w in words if w not in stopwords) 
wc = WordCloud(stopwords=STOPWORDS,background_color='white',mask=origin_mask, contour_width=3, 
               contour_color='steelblue').generate(" ".join(words_without_stop))
plt.imshow(wc)
fig=plt.gcf()
fig.set_size_inches(14,9)
plt.axis('off')
plt.show()
# Out:
# C:\Users\hm-wa14\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
import nltk
from wordcloud import WordCloud, STOPWORDS
motive=df['event_name'].str.cat(sep = '-')

# motive=df['event_name'].str().lower().str.cat(sep=' ')
words=nltk.tokenize.word_tokenize(motive)

# words = [i for i in df['event_name']]
# print(words)

word_dist = nltk.FreqDist(words)
stopwords = nltk.corpus.stopwords.words('english')

origin_image = imread("statue-of-liberty.png")
origin_mask = origin_image
words_without_stop = nltk.FreqDist(w for w in words) 
wc = WordCloud(stopwords=STOPWORDS,background_color='white',mask=origin_mask, contour_width=3, 
               contour_color='steelblue').generate(" ".join(words_without_stop))
plt.imshow(wc)
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.axis('off')
plt.show()
# Out:
# C:\Users\hm-wa14\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
